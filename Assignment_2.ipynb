# %% [markdown]
# # 1. Loading and processing the data

# %% [markdown]
# 1.

# %%
library(hdm)
library(xtable)
library(glmnet)
library(ggplot2)
library(tidyr)
library(caret)

# %%
file<- "https://raw.githubusercontent.com/d2cml-ai/CausalAI-Course/main/data/wage2015_subsample_inference.csv"
data <- read.csv(file)
colnames(data)
# Out:
#  [1] "rownames" "wage"     "lwage"    "sex"      "shs"      "hsg"
#  [7] "scl"      "clg"      "ad"       "mw"       "so"       "we"
# [13] "ne"       "exp1"     "exp2"     "exp3"     "exp4"     "occ"
# [19] "occ2"     "ind"      "ind2"

# %%
data <- subset(data, select = -c(rownames))
dim(data)[2]
# Out:
# [1] 20

# %%
features <- data[,!names(data) %in% c('wage','lwage')]
dependent_var <- data['lwage']

# %%
features_flexible <- model.matrix(~ 0 + sex + (exp1 + exp2 + exp3 + exp4 + hsg + scl + clg + ad + so + we + ne + 
                                         factor(occ2) + factor(ind2))^2, data = features)

# %%
dependent_var<- as.matrix(dependent_var)
features_flexible<- as.matrix(features_flexible)

# %% [markdown]
# 2.

# %% [markdown]
# # 2. Creating Lasso Cross-Validation Procedure

# %% [markdown]
# Log_grid function

# %%
log_grid <- function(lower, upper, log_step) {
  log_grid <- seq(lower, upper, length.out = 1 / log_step)
  return(exp(log_grid))
}

# %% [markdown]
# K-fold procedure

# %%
k_folds <- function(data, k = 5) {
  
  module <- nrow(data) %% k
  floor <- nrow(data) %/% k 
  
  if (module == 0) {
    trues <- matrix(1, nrow = floor, ncol = 1)
    split_matrix <- kronecker(diag(k), trues)
  } else {
    trues_g1 <- matrix(1, nrow = floor + 1, ncol = 1)
    split_matrix_g1 <- kronecker(diag(module), trues_g1)
    
    trues_g2 <- matrix(1, nrow = floor, ncol = 1)
    split_matrix_g2 <- kronecker(diag(k - module), trues_g2)
    
    split_matrix <- rbind(
      cbind(split_matrix_g1, matrix(0, nrow = nrow(split_matrix_g1), ncol = ncol(split_matrix_g2))),
      cbind(matrix(0, nrow = nrow(split_matrix_g2), ncol = ncol(split_matrix_g1)), split_matrix_g2)
    )
  }
  
  sm_bool <- split_matrix == 1
  splits <- lapply(1:k, function(x) sm_bool[, x])
  
  return(splits)
}

# %% [markdown]
# Optimal_lambda procedure

# %%
optimal_lambda <- function(Y, X, lambda_bounds, k = 5, niter = 100) {
  
  library(glmnet)
  
  Y <- drop(Y)
  
  if (is.vector(X)) {
    X <- matrix(X, ncol = 1)
  }
  
  folds <- k_folds(X, k)
  all_lambdas <- exp(seq(lambda_bounds[1], lambda_bounds[2], length.out = niter))
  all_mse <- numeric(niter)
  
  for (l in all_lambdas) {
    split_pes <- numeric(k)
    
    for (i in seq_len(k)) {
      X_train <- X[!folds[[i]], ]
      X_test <- X[folds[[i]], ]
      y_train <- Y[!folds[[i]]]
      y_test <- Y[folds[[i]]]
      
      model <- glmnet(X_train, y_train, alpha = 1, lambda = l,standardize = FALSE)
      predict <- predict(model, X_test, s = l)
      
      pe <- sum((y_test - predict)^2)
      split_pes[i] <- pe
    }
    
    all_mse[which(all_lambdas == l)] <- mean(split_pes)
  }
  
  selected <- which.min(all_mse)
  optimal_lambda <- all_lambdas[selected]
  optimal_model <- glmnet(X, Y, alpha = 1, lambda = optimal_lambda)
  optimal_coef <- coef(optimal_model, s = optimal_lambda)
  
  output <- list(
    optimal_lambda = optimal_lambda,
    optimal_coef = optimal_coef,
    all_lambdas = all_lambdas,
    all_mse = all_mse
  )
  
  return(output)
}

# %% [markdown]
# Prediction model

# %%
predict_model <- function(optimal_model, X) {
  
  intercept <- matrix(1, nrow = nrow(X), ncol = 1)
  Z <- cbind(intercept, X)
  
  return(Z %*% optimal_model$optimal_coef)
}

# %% [markdown]
# ## Applying the lasso cross-validation procedure

# %%
library(caTools)

split <- sample.split(dependent_var, SplitRatio = 0.75)
features_flexible_train <- subset(features_flexible, split == TRUE)
features_flexible_test <- subset(features_flexible, split == FALSE)
dependent_train <- dependent_var[split]
dependent_test <- dependent_var[!split]

# %% [markdown]
# Ols fitting

# %%
ols <- lm(dependent_train ~ ., data = data.frame(dependent_train = dependent_train, features_flexible_train))

# %% [markdown]
# Finding optimal lambda

# %%
model_lasso <- optimal_lambda(dependent_train, features_flexible_train, c(-7, 7))

# %%
model_lasso$optimal_lambda
# Out:
# [1] 0.001605462

# %%
model_lasso$optimal_coef
# Out:
# 981 x 1 sparse Matrix of class "dgCMatrix"
#                                          s1
# (Intercept)                    2.680768e+00
# sex                           -5.731770e-02
# exp1                           8.760830e-03
# exp2                           .
# exp3                           .
# exp4                           .
# hsg                            .
# scl                            .
# clg                            3.188792e-01
# ad                             3.367445e-01
# so                             .
# we                             2.956107e-02
# ne                             .
# factor(occ2)1                  2.794073e-01
# factor(occ2)2                  2.112206e-01
# factor(occ2)3                  9.837338e-02
# factor(occ2)4                  1.040519e-01
# factor(occ2)5                  .
# factor(occ2)6                 -8.393052e-02
# factor(occ2)7                  .
# factor(occ2)8                 -6.113334e-03
# factor(occ2)9                  .
# factor(occ2)10                 .
# factor(occ2)11                -3.285746e-02
# factor(occ2)12                 .
# factor(occ2)13                 .
# factor(occ2)14                 .
# factor(occ2)15                 .
# factor(occ2)16                 1.148950e-01
# factor(occ2)17                -8.309395e-02
# factor(occ2)18                 .
# factor(occ2)19                 8.594871e-02
# factor(occ2)20                -2.028250e-02
# factor(occ2)21                 .
# factor(occ2)22                -1.082511e-01
# factor(ind2)3                  .
# factor(ind2)4                  .
# factor(ind2)5                  .
# factor(ind2)6                  .
# factor(ind2)7                  .
# factor(ind2)8                  .
# factor(ind2)9                  .
# factor(ind2)10                 .
# factor(ind2)11                 .
# factor(ind2)12                 2.093173e-01
# factor(ind2)13                 .
# factor(ind2)14                 7.868980e-03
# factor(ind2)15                -6.473300e-02
# factor(ind2)16                -9.970461e-03
# factor(ind2)17                -1.166117e-02
# factor(ind2)18                -7.568136e-02
# factor(ind2)19                -3.144453e-03
# factor(ind2)20                -2.293538e-01
# factor(ind2)21                 .
# factor(ind2)22                 .
# exp1:exp2                      .
# exp1:exp3                      .
# exp1:exp4                      .
# exp1:hsg                       .
# exp1:scl                       1.306445e-03
# exp1:clg                       .
# exp1:ad                        2.592199e-03
# exp1:so                        3.226622e-03
# exp1:we                        3.795471e-03
# exp1:ne                        5.476766e-04
# exp1:factor(occ2)2             .
# exp1:factor(occ2)3             .
# exp1:factor(occ2)4            -1.583457e-03
# exp1:factor(occ2)5             6.537530e-03
# exp1:factor(occ2)6             .
# exp1:factor(occ2)7             2.412069e-03
# exp1:factor(occ2)8             .
# exp1:factor(occ2)9             9.731282e-03
# exp1:factor(occ2)10            1.310556e-02
# exp1:factor(occ2)11           -6.523006e-03
# exp1:factor(occ2)12            5.550415e-03
# exp1:factor(occ2)13           -5.320873e-03
# exp1:factor(occ2)14           -7.819602e-03
# exp1:factor(occ2)15           -4.476962e-03
# exp1:factor(occ2)16            1.114083e-02
# exp1:factor(occ2)17            .
# exp1:factor(occ2)18            .
# exp1:factor(occ2)19            1.977689e-03
# exp1:factor(occ2)20            .
# exp1:factor(occ2)21           -9.558516e-05
# exp1:factor(occ2)22            .
# exp1:factor(ind2)3             .
# exp1:factor(ind2)4            -3.745568e-03
# exp1:factor(ind2)5             .
# exp1:factor(ind2)6             .
# exp1:factor(ind2)7             .
# exp1:factor(ind2)8             .
# exp1:factor(ind2)9             3.789325e-04
# exp1:factor(ind2)10            2.371482e-03
# exp1:factor(ind2)11            .
# exp1:factor(ind2)12            .
# exp1:factor(ind2)13           -7.194950e-04
# exp1:factor(ind2)14            .
# exp1:factor(ind2)15            .
# exp1:factor(ind2)16            .
# exp1:factor(ind2)17            1.922194e-03
# exp1:factor(ind2)18           -1.395717e-04
# exp1:factor(ind2)19            .
# exp1:factor(ind2)20           -2.731573e-03
# exp1:factor(ind2)21           -1.789355e-03
# exp1:factor(ind2)22            5.734044e-03
# exp2:exp3                      .
# exp2:exp4                      .
# exp2:hsg                       .
# exp2:scl                       .
# exp2:clg                       .
# exp2:ad                        .
# exp2:so                        .
# exp2:we                        .
# exp2:ne                        1.698298e-03
# exp2:factor(occ2)2             .
# exp2:factor(occ2)3             .
# exp2:factor(occ2)4            -7.405562e-03
# exp2:factor(occ2)5             .
# exp2:factor(occ2)6             .
# exp2:factor(occ2)7             .
# exp2:factor(occ2)8             .
# exp2:factor(occ2)9             .
# exp2:factor(occ2)10            .
# exp2:factor(occ2)11            .
# exp2:factor(occ2)12            .
# exp2:factor(occ2)13            .
# exp2:factor(occ2)14            .
# exp2:factor(occ2)15            .
# exp2:factor(occ2)16            .
# exp2:factor(occ2)17            .
# exp2:factor(occ2)18            .
# exp2:factor(occ2)19            .
# exp2:factor(occ2)20            .
# exp2:factor(occ2)21            .
# exp2:factor(occ2)22            .
# exp2:factor(ind2)3             .
# exp2:factor(ind2)4             .
# exp2:factor(ind2)5             .
# exp2:factor(ind2)6             5.648638e-04
# exp2:factor(ind2)7             1.260209e-02
# exp2:factor(ind2)8            -3.432306e-02
# exp2:factor(ind2)9             .
# exp2:factor(ind2)10            .
# exp2:factor(ind2)11            .
# exp2:factor(ind2)12            .
# exp2:factor(ind2)13           -4.500494e-03
# exp2:factor(ind2)14            .
# exp2:factor(ind2)15            .
# exp2:factor(ind2)16            .
# exp2:factor(ind2)17            .
# exp2:factor(ind2)18            .
# exp2:factor(ind2)19            3.051139e-03
# exp2:factor(ind2)20            .
# exp2:factor(ind2)21            .
# exp2:factor(ind2)22            .
# exp3:exp4                     -5.163681e-06
# exp3:hsg                       2.270714e-04
# exp3:scl                       .
# exp3:clg                       .
# exp3:ad                        .
# exp3:so                        .
# exp3:we                        .
# exp3:ne                        4.414377e-04
# exp3:factor(occ2)2            -5.064942e-03
# exp3:factor(occ2)3             .
# exp3:factor(occ2)4             .
# exp3:factor(occ2)5             .
# exp3:factor(occ2)6             .
# exp3:factor(occ2)7             .
# exp3:factor(occ2)8             7.197356e-05
# exp3:factor(occ2)9             .
# exp3:factor(occ2)10            .
# exp3:factor(occ2)11            .
# exp3:factor(occ2)12            .
# exp3:factor(occ2)13            .
# exp3:factor(occ2)14            .
# exp3:factor(occ2)15            .
# exp3:factor(occ2)16            .
# exp3:factor(occ2)17            .
# exp3:factor(occ2)18            .
# exp3:factor(occ2)19            .
# exp3:factor(occ2)20            .
# exp3:factor(occ2)21            .
# exp3:factor(occ2)22           -1.775006e-04
# exp3:factor(ind2)3             .
# exp3:factor(ind2)4             .
# exp3:factor(ind2)5             1.459949e-03
# exp3:factor(ind2)6             .
# exp3:factor(ind2)7             .
# exp3:factor(ind2)8             .
# exp3:factor(ind2)9             .
# exp3:factor(ind2)10            .
# exp3:factor(ind2)11            .
# exp3:factor(ind2)12           -4.011239e-03
# exp3:factor(ind2)13            .
# exp3:factor(ind2)14            .
# exp3:factor(ind2)15            .
# exp3:factor(ind2)16            .
# exp3:factor(ind2)17            .
# exp3:factor(ind2)18            .
# exp3:factor(ind2)19            2.222448e-03
# exp3:factor(ind2)20           -1.587727e-03
# exp3:factor(ind2)21            .
# exp3:factor(ind2)22            .
# exp4:hsg                       4.405691e-04
# exp4:scl                       .
# exp4:clg                       .
# exp4:ad                       -5.123865e-04
# exp4:so                        .
# exp4:we                       -1.570123e-04
# exp4:ne                        6.878496e-04
# exp4:factor(occ2)2            -1.217529e-04
# exp4:factor(occ2)3             8.306318e-04
# exp4:factor(occ2)4             .
# exp4:factor(occ2)5            -7.426731e-04
# exp4:factor(occ2)6            -1.034273e-03
# exp4:factor(occ2)7             .
# exp4:factor(occ2)8             2.695052e-05
# exp4:factor(occ2)9            -1.817616e-03
# exp4:factor(occ2)10           -2.435036e-03
# exp4:factor(occ2)11            .
# exp4:factor(occ2)12           -6.368980e-04
# exp4:factor(occ2)13            .
# exp4:factor(occ2)14            .
# exp4:factor(occ2)15            .
# exp4:factor(occ2)16           -2.824565e-03
# exp4:factor(occ2)17           -6.562875e-04
# exp4:factor(occ2)18            .
# exp4:factor(occ2)19            .
# exp4:factor(occ2)20            .
# exp4:factor(occ2)21           -1.375620e-03
# exp4:factor(occ2)22           -5.282343e-05
# exp4:factor(ind2)3             1.889983e-04
# exp4:factor(ind2)4            -2.975960e-04
# exp4:factor(ind2)5             .
# exp4:factor(ind2)6             .
# exp4:factor(ind2)7             .
# exp4:factor(ind2)8             .
# exp4:factor(ind2)9             3.567121e-04
# exp4:factor(ind2)10            .
# exp4:factor(ind2)11            .
# exp4:factor(ind2)12            .
# exp4:factor(ind2)13            .
# exp4:factor(ind2)14            9.090632e-05
# exp4:factor(ind2)15           -1.028964e-04
# exp4:factor(ind2)16           -8.757254e-04
# exp4:factor(ind2)17            .
# exp4:factor(ind2)18            .
# exp4:factor(ind2)19            7.936575e-05
# exp4:factor(ind2)20           -7.119354e-04
# exp4:factor(ind2)21           -3.592704e-04
# exp4:factor(ind2)22           -1.863404e-03
# hsg:scl                        .
# hsg:clg                        .
# hsg:ad                         .
# hsg:so                        -8.178279e-02
# hsg:we                         .
# hsg:ne                         2.041503e-02
# hsg:factor(occ2)2             -1.401889e-01
# hsg:factor(occ2)3             -1.102921e-01
# hsg:factor(occ2)4              .
# hsg:factor(occ2)5              3.880271e-02
# hsg:factor(occ2)6              2.254462e-02
# hsg:factor(occ2)7             -1.466964e-01
# hsg:factor(occ2)8             -2.028709e-01
# hsg:factor(occ2)9             -1.067098e-01
# hsg:factor(occ2)10            -4.262982e-02
# hsg:factor(occ2)11             .
# hsg:factor(occ2)12            -1.761100e-01
# hsg:factor(occ2)13             .
# hsg:factor(occ2)14             .
# hsg:factor(occ2)15            -1.038779e-02
# hsg:factor(occ2)16            -2.085385e-01
# hsg:factor(occ2)17            -6.654185e-04
# hsg:factor(occ2)18            -1.609431e-01
# hsg:factor(occ2)19             1.282694e-01
# hsg:factor(occ2)20             2.760321e-01
# hsg:factor(occ2)21             7.198855e-02
# hsg:factor(occ2)22             5.295315e-02
# hsg:factor(ind2)3             -1.935800e-03
# hsg:factor(ind2)4              .
# hsg:factor(ind2)5             -1.654959e-02
# hsg:factor(ind2)6             -1.294346e-01
# hsg:factor(ind2)7              4.610498e-02
# hsg:factor(ind2)8              1.710218e-01
# hsg:factor(ind2)9             -1.149629e-01
# hsg:factor(ind2)10             3.018616e-02
# hsg:factor(ind2)11             2.325880e-01
# hsg:factor(ind2)12             1.196698e-02
# hsg:factor(ind2)13             4.900570e-02
# hsg:factor(ind2)14             .
# hsg:factor(ind2)15             .
# hsg:factor(ind2)16             1.149236e-01
# hsg:factor(ind2)17             .
# hsg:factor(ind2)18             .
# hsg:factor(ind2)19            -2.633689e-01
# hsg:factor(ind2)20             .
# hsg:factor(ind2)21            -2.559622e-01
# hsg:factor(ind2)22             8.157707e-02
# scl:clg                        .
# scl:ad                         .
# scl:so                         1.964734e-02
# scl:we                         5.868147e-02
# scl:ne                         .
# scl:factor(occ2)2              1.607898e-01
# scl:factor(occ2)3              5.801773e-02
# scl:factor(occ2)4              .
# scl:factor(occ2)5             -2.601751e-01
# scl:factor(occ2)6              .
# scl:factor(occ2)7             -1.491821e-01
# scl:factor(occ2)8             -2.198509e-01
# scl:factor(occ2)9              .
# scl:factor(occ2)10             5.945206e-02
# scl:factor(occ2)11             .
# scl:factor(occ2)12             1.281145e-01
# scl:factor(occ2)13             .
# scl:factor(occ2)14             1.461557e-02
# scl:factor(occ2)15            -3.217259e-02
# scl:factor(occ2)16            -1.893132e-01
# scl:factor(occ2)17             .
# scl:factor(occ2)18             6.180472e-01
# scl:factor(occ2)19             2.478902e-01
# scl:factor(occ2)20             2.243741e-01
# scl:factor(occ2)21             6.720047e-02
# scl:factor(occ2)22             .
# scl:factor(ind2)3              .
# scl:factor(ind2)4              .
# scl:factor(ind2)5             -1.098349e-01
# scl:factor(ind2)6              2.534345e-02
# scl:factor(ind2)7              1.115318e-01
# scl:factor(ind2)8              4.075478e-02
# scl:factor(ind2)9             -1.222588e-01
# scl:factor(ind2)10             .
# scl:factor(ind2)11             4.814641e-02
# scl:factor(ind2)12             8.804043e-02
# scl:factor(ind2)13            -1.406775e-01
# scl:factor(ind2)14             6.637796e-02
# scl:factor(ind2)15            -4.885477e-02
# scl:factor(ind2)16             1.035154e-01
# scl:factor(ind2)17             .
# scl:factor(ind2)18             .
# scl:factor(ind2)19             .
# scl:factor(ind2)20            -6.622514e-03
# scl:factor(ind2)21            -3.676997e-02
# scl:factor(ind2)22             4.983676e-02
# clg:ad                         .
# clg:so                         2.236162e-02
# clg:we                        -6.466113e-02
# clg:ne                         .
# clg:factor(occ2)2              .
# clg:factor(occ2)3              8.843487e-02
# clg:factor(occ2)4              1.693428e-01
# clg:factor(occ2)5              .
# clg:factor(occ2)6             -1.095767e-01
# clg:factor(occ2)7             -8.702126e-02
# clg:factor(occ2)8              .
# clg:factor(occ2)9              7.149723e-03
# clg:factor(occ2)10             9.088385e-02
# clg:factor(occ2)11             .
# clg:factor(occ2)12             2.640255e-01
# clg:factor(occ2)13             .
# clg:factor(occ2)14             2.066924e-01
# clg:factor(occ2)15             .
# clg:factor(occ2)16             .
# clg:factor(occ2)17             .
# clg:factor(occ2)18             .
# clg:factor(occ2)19             6.612301e-03
# clg:factor(occ2)20            -8.313813e-02
# clg:factor(occ2)21            -1.393250e-01
# clg:factor(occ2)22            -2.034912e-02
# clg:factor(ind2)3              3.194740e-01
# clg:factor(ind2)4             -6.378385e-02
# clg:factor(ind2)5              3.867106e-02
# clg:factor(ind2)6              2.393776e-02
# clg:factor(ind2)7             -1.978484e-01
# clg:factor(ind2)8             -1.035679e-01
# clg:factor(ind2)9             -3.106181e-01
# clg:factor(ind2)10             .
# clg:factor(ind2)11             .
# clg:factor(ind2)12             .
# clg:factor(ind2)13             1.041434e-01
# clg:factor(ind2)14             .
# clg:factor(ind2)15             .
# clg:factor(ind2)16             .
# clg:factor(ind2)17            -1.242224e-01
# clg:factor(ind2)18             .
# clg:factor(ind2)19            -1.253699e-01
# clg:factor(ind2)20            -6.532729e-02
# clg:factor(ind2)21             2.524106e-02
# clg:factor(ind2)22             .
# ad:so                          8.937294e-02
# ad:we                          .
# ad:ne                         -2.429083e-02
# ad:factor(occ2)2               4.433364e-02
# ad:factor(occ2)3               .
# ad:factor(occ2)4              -5.561754e-02
# ad:factor(occ2)5               .
# ad:factor(occ2)6              -2.485630e-01
# ad:factor(occ2)7               4.380852e-01
# ad:factor(occ2)8               .
# ad:factor(occ2)9              -1.707426e-01
# ad:factor(occ2)10              .
# ad:factor(occ2)11             -4.411892e-01
# ad:factor(occ2)12             -9.360705e-02
# ad:factor(occ2)13             -4.344810e-01
# ad:factor(occ2)14              2.154911e-02
# ad:factor(occ2)15              .
# ad:factor(occ2)16             -2.902067e-02
# ad:factor(occ2)17              .
# ad:factor(occ2)18              .
# ad:factor(occ2)19             -6.312268e-01
# ad:factor(occ2)20              .
# ad:factor(occ2)21             -1.347195e-01
# ad:factor(occ2)22             -8.175024e-01
# ad:factor(ind2)3              -5.951911e-01
# ad:factor(ind2)4               4.184779e-01
# ad:factor(ind2)5               2.890231e-01
# ad:factor(ind2)6               .
# ad:factor(ind2)7               .
# ad:factor(ind2)8               3.433899e-01
# ad:factor(ind2)9               5.081478e-02
# ad:factor(ind2)10             -7.253450e-02
# ad:factor(ind2)11              .
# ad:factor(ind2)12              .
# ad:factor(ind2)13              5.673911e-02
# ad:factor(ind2)14              1.373621e-01
# ad:factor(ind2)15              .
# ad:factor(ind2)16              1.720520e-01
# ad:factor(ind2)17             -2.803605e-02
# ad:factor(ind2)18              1.932050e-01
# ad:factor(ind2)19              .
# ad:factor(ind2)20              1.431878e-01
# ad:factor(ind2)21              .
# ad:factor(ind2)22              .
# so:we                          .
# so:ne                          .
# so:factor(occ2)2              -6.557769e-02
# so:factor(occ2)3               .
# so:factor(occ2)4               .
# so:factor(occ2)5              -2.935450e-02
# so:factor(occ2)6               7.033404e-02
# so:factor(occ2)7              -1.340941e-01
# so:factor(occ2)8               .
# so:factor(occ2)9               .
# so:factor(occ2)10              2.714005e-02
# so:factor(occ2)11             -3.582347e-02
# so:factor(occ2)12             -3.876861e-01
# so:factor(occ2)13              .
# so:factor(occ2)14              .
# so:factor(occ2)15             -5.394311e-02
# so:factor(occ2)16             -1.488826e-01
# so:factor(occ2)17             -3.319069e-02
# so:factor(occ2)18              .
# so:factor(occ2)19             -1.314004e-01
# so:factor(occ2)20             -8.274078e-02
# so:factor(occ2)21              7.818205e-02
# so:factor(occ2)22             -6.682191e-02
# so:factor(ind2)3               1.664054e-01
# so:factor(ind2)4               .
# so:factor(ind2)5               8.407556e-03
# so:factor(ind2)6              -5.153283e-02
# so:factor(ind2)7               6.288464e-04
# so:factor(ind2)8               1.487173e-01
# so:factor(ind2)9              -7.525641e-03
# so:factor(ind2)10              .
# so:factor(ind2)11             -8.145710e-02
# so:factor(ind2)12             -5.929469e-02
# so:factor(ind2)13              .
# so:factor(ind2)14              .
# so:factor(ind2)15             -1.358106e-01
# so:factor(ind2)16             -1.014829e-01
# so:factor(ind2)17             -9.021527e-02
# so:factor(ind2)18              .
# so:factor(ind2)19             -4.808864e-03
# so:factor(ind2)20             -7.343456e-02
# so:factor(ind2)21              7.335893e-02
# so:factor(ind2)22              1.980015e-01
# we:ne                          .
# we:factor(occ2)2               .
# we:factor(occ2)3               8.203088e-02
# we:factor(occ2)4               .
# we:factor(occ2)5               2.343916e-01
# we:factor(occ2)6               .
# we:factor(occ2)7              -1.500448e-01
# we:factor(occ2)8               .
# we:factor(occ2)9              -1.521350e-01
# we:factor(occ2)10              4.349824e-02
# we:factor(occ2)11             -3.437081e-02
# we:factor(occ2)12             -1.790210e-01
# we:factor(occ2)13             -3.967008e-02
# we:factor(occ2)14             -8.024970e-02
# we:factor(occ2)15             -7.529085e-03
# we:factor(occ2)16              7.934444e-02
# we:factor(occ2)17              .
# we:factor(occ2)18              .
# we:factor(occ2)19              3.761401e-02
# we:factor(occ2)20             -1.027890e-01
# we:factor(occ2)21             -5.190967e-02
# we:factor(occ2)22              .
# we:factor(ind2)3               1.877842e-01
# we:factor(ind2)4               .
# we:factor(ind2)5               3.464347e-02
# we:factor(ind2)6              -5.395081e-02
# we:factor(ind2)7               1.464972e-01
# we:factor(ind2)8               4.062826e-01
# we:factor(ind2)9               7.686881e-03
# we:factor(ind2)10             -9.171270e-02
# we:factor(ind2)11              1.417891e-01
# we:factor(ind2)12             -2.341033e-02
# we:factor(ind2)13              .
# we:factor(ind2)14             -5.714175e-02
# we:factor(ind2)15              1.780414e-01
# we:factor(ind2)16             -2.601422e-01
# we:factor(ind2)17              .
# we:factor(ind2)18             -2.050608e-03
# we:factor(ind2)19              2.067987e-02
# we:factor(ind2)20              .
# we:factor(ind2)21              .
# we:factor(ind2)22              3.897512e-03
# ne:factor(occ2)2               .
# ne:factor(occ2)3               .
# ne:factor(occ2)4               .
# ne:factor(occ2)5               7.902314e-02
# ne:factor(occ2)6               1.366886e-01
# ne:factor(occ2)7               8.578583e-02
# ne:factor(occ2)8               9.839564e-02
# ne:factor(occ2)9               1.513077e-01
# ne:factor(occ2)10              2.763678e-01
# ne:factor(occ2)11              4.293562e-02
# ne:factor(occ2)12              5.182481e-02
# ne:factor(occ2)13              .
# ne:factor(occ2)14              .
# ne:factor(occ2)15              6.778523e-02
# ne:factor(occ2)16             -7.259869e-02
# ne:factor(occ2)17              1.925272e-02
# ne:factor(occ2)18              8.841376e-03
# ne:factor(occ2)19              .
# ne:factor(occ2)20             -1.265946e-01
# ne:factor(occ2)21             -4.502984e-02
# ne:factor(occ2)22              .
# ne:factor(ind2)3              -5.304329e-02
# ne:factor(ind2)4               4.035771e-04
# ne:factor(ind2)5              -7.833515e-02
# ne:factor(ind2)6              -8.805913e-03
# ne:factor(ind2)7               4.853224e-02
# ne:factor(ind2)8               .
# ne:factor(ind2)9              -3.250398e-02
# ne:factor(ind2)10             -2.014321e-01
# ne:factor(ind2)11              5.565197e-02
# ne:factor(ind2)12              .
# ne:factor(ind2)13              .
# ne:factor(ind2)14              3.147293e-02
# ne:factor(ind2)15              5.846908e-01
# ne:factor(ind2)16              .
# ne:factor(ind2)17             -3.354992e-02
# ne:factor(ind2)18             -1.610320e-01
# ne:factor(ind2)19              .
# ne:factor(ind2)20              .
# ne:factor(ind2)21              .
# ne:factor(ind2)22              2.820461e-02
# factor(occ2)2:factor(ind2)3   -3.338243e-01
# factor(occ2)3:factor(ind2)3    .
# factor(occ2)4:factor(ind2)3   -9.114470e-02
# factor(occ2)5:factor(ind2)3    .
# factor(occ2)6:factor(ind2)3    .
# factor(occ2)7:factor(ind2)3    .
# factor(occ2)8:factor(ind2)3    .
# factor(occ2)9:factor(ind2)3    .
# factor(occ2)10:factor(ind2)3   .
# factor(occ2)11:factor(ind2)3   .
# factor(occ2)12:factor(ind2)3  -2.894457e-01
# factor(occ2)13:factor(ind2)3   .
# factor(occ2)14:factor(ind2)3   .
# factor(occ2)15:factor(ind2)3   .
# factor(occ2)16:factor(ind2)3   .
# factor(occ2)17:factor(ind2)3  -2.979177e-01
# factor(occ2)18:factor(ind2)3   .
# factor(occ2)19:factor(ind2)3  -2.788729e-01
# factor(occ2)20:factor(ind2)3   3.158017e-01
# factor(occ2)21:factor(ind2)3   2.405224e-01
# factor(occ2)22:factor(ind2)3   .
# factor(occ2)2:factor(ind2)4    1.063284e-01
# factor(occ2)3:factor(ind2)4    2.006022e-02
# factor(occ2)4:factor(ind2)4    .
# factor(occ2)5:factor(ind2)4    .
# factor(occ2)6:factor(ind2)4    .
# factor(occ2)7:factor(ind2)4    .
# factor(occ2)8:factor(ind2)4    .
# factor(occ2)9:factor(ind2)4    .
# factor(occ2)10:factor(ind2)4   .
# factor(occ2)11:factor(ind2)4   .
# factor(occ2)12:factor(ind2)4   .
# factor(occ2)13:factor(ind2)4   .
# factor(occ2)14:factor(ind2)4   .
# factor(occ2)15:factor(ind2)4   .
# factor(occ2)16:factor(ind2)4   3.374372e-01
# factor(occ2)17:factor(ind2)4   5.267870e-02
# factor(occ2)18:factor(ind2)4   .
# factor(occ2)19:factor(ind2)4  -1.677294e-01
# factor(occ2)20:factor(ind2)4   .
# factor(occ2)21:factor(ind2)4   1.919220e-01
# factor(occ2)22:factor(ind2)4   1.610978e-01
# factor(occ2)2:factor(ind2)5    9.746035e-02
# factor(occ2)3:factor(ind2)5    .
# factor(occ2)4:factor(ind2)5    1.119105e-01
# factor(occ2)5:factor(ind2)5    1.424775e-02
# factor(occ2)6:factor(ind2)5    .
# factor(occ2)7:factor(ind2)5    .
# factor(occ2)8:factor(ind2)5    .
# factor(occ2)9:factor(ind2)5   -2.458722e-01
# factor(occ2)10:factor(ind2)5  -5.445752e-01
# factor(occ2)11:factor(ind2)5   .
# factor(occ2)12:factor(ind2)5   .
# factor(occ2)13:factor(ind2)5  -1.054165e-01
# factor(occ2)14:factor(ind2)5  -6.539741e-02
# factor(occ2)15:factor(ind2)5   .
# factor(occ2)16:factor(ind2)5   .
# factor(occ2)17:factor(ind2)5   .
# factor(occ2)18:factor(ind2)5  -4.964679e-04
# factor(occ2)19:factor(ind2)5   .
# factor(occ2)20:factor(ind2)5   .
# factor(occ2)21:factor(ind2)5  -7.177548e-02
# factor(occ2)22:factor(ind2)5  -2.844719e-01
# factor(occ2)2:factor(ind2)6    3.879608e-02
# factor(occ2)3:factor(ind2)6    3.940768e-01
# factor(occ2)4:factor(ind2)6    1.365710e-01
# factor(occ2)5:factor(ind2)6    4.773200e-01
# factor(occ2)6:factor(ind2)6    .
# factor(occ2)7:factor(ind2)6    .
# factor(occ2)8:factor(ind2)6    .
# factor(occ2)9:factor(ind2)6   -1.315950e-02
# factor(occ2)10:factor(ind2)6   .
# factor(occ2)11:factor(ind2)6   .
# factor(occ2)12:factor(ind2)6   .
# factor(occ2)13:factor(ind2)6   .
# factor(occ2)14:factor(ind2)6  -1.200878e-01
# factor(occ2)15:factor(ind2)6   .
# factor(occ2)16:factor(ind2)6   2.210833e-01
# factor(occ2)17:factor(ind2)6  -2.210078e-02
# factor(occ2)18:factor(ind2)6   .
# factor(occ2)19:factor(ind2)6   .
# factor(occ2)20:factor(ind2)6  -1.030360e-01
# factor(occ2)21:factor(ind2)6   .
# factor(occ2)22:factor(ind2)6  -1.599716e-01
# factor(occ2)2:factor(ind2)7    5.417653e-03
# factor(occ2)3:factor(ind2)7    4.075627e-01
# factor(occ2)4:factor(ind2)7    .
# factor(occ2)5:factor(ind2)7    .
# factor(occ2)6:factor(ind2)7    .
# factor(occ2)7:factor(ind2)7    .
# factor(occ2)8:factor(ind2)7    .
# factor(occ2)9:factor(ind2)7    .
# factor(occ2)10:factor(ind2)7   .
# factor(occ2)11:factor(ind2)7   .
# factor(occ2)12:factor(ind2)7   .
# factor(occ2)13:factor(ind2)7   1.245680e-02
# factor(occ2)14:factor(ind2)7   .
# factor(occ2)15:factor(ind2)7   .
# factor(occ2)16:factor(ind2)7   2.899106e-01
# factor(occ2)17:factor(ind2)7  -2.129600e-01
# factor(occ2)18:factor(ind2)7   .
# factor(occ2)19:factor(ind2)7   .
# factor(occ2)20:factor(ind2)7   1.374422e-01
# factor(occ2)21:factor(ind2)7  -1.254841e-01
# factor(occ2)22:factor(ind2)7  -2.137854e-01
# factor(occ2)2:factor(ind2)8   -3.481678e-01
# factor(occ2)3:factor(ind2)8   -5.186616e-01
# factor(occ2)4:factor(ind2)8    .
# factor(occ2)5:factor(ind2)8    .
# factor(occ2)6:factor(ind2)8    .
# factor(occ2)7:factor(ind2)8    .
# factor(occ2)8:factor(ind2)8    .
# factor(occ2)9:factor(ind2)8    .
# factor(occ2)10:factor(ind2)8   .
# factor(occ2)11:factor(ind2)8   .
# factor(occ2)12:factor(ind2)8   3.482369e-01
# factor(occ2)13:factor(ind2)8   .
# factor(occ2)14:factor(ind2)8   1.767548e-01
# factor(occ2)15:factor(ind2)8   .
# factor(occ2)16:factor(ind2)8   3.115924e-02
# factor(occ2)17:factor(ind2)8  -3.729612e-01
# factor(occ2)18:factor(ind2)8   .
# factor(occ2)19:factor(ind2)8   .
# factor(occ2)20:factor(ind2)8   .
# factor(occ2)21:factor(ind2)8   .
# factor(occ2)22:factor(ind2)8  -1.153402e-01
# factor(occ2)2:factor(ind2)9    2.361956e-01
# factor(occ2)3:factor(ind2)9   -2.013876e-01
# factor(occ2)4:factor(ind2)9    .
# factor(occ2)5:factor(ind2)9    .
# factor(occ2)6:factor(ind2)9    .
# factor(occ2)7:factor(ind2)9    5.995547e-01
# factor(occ2)8:factor(ind2)9    .
# factor(occ2)9:factor(ind2)9    8.348480e-02
# factor(occ2)10:factor(ind2)9   2.080128e-01
# factor(occ2)11:factor(ind2)9   .
# factor(occ2)12:factor(ind2)9  -1.984472e-01
# factor(occ2)13:factor(ind2)9  -2.345957e-01
# factor(occ2)14:factor(ind2)9  -3.105837e-01
# factor(occ2)15:factor(ind2)9   8.310979e-02
# factor(occ2)16:factor(ind2)9  -3.931012e-02
# factor(occ2)17:factor(ind2)9   .
# factor(occ2)18:factor(ind2)9   .
# factor(occ2)19:factor(ind2)9  -1.224024e-01
# factor(occ2)20:factor(ind2)9   .
# factor(occ2)21:factor(ind2)9  -1.231941e-01
# factor(occ2)22:factor(ind2)9   .
# factor(occ2)2:factor(ind2)10  -2.079630e-01
# factor(occ2)3:factor(ind2)10  -3.490227e-01
# factor(occ2)4:factor(ind2)10   .
# factor(occ2)5:factor(ind2)10   .
# factor(occ2)6:factor(ind2)10   .
# factor(occ2)7:factor(ind2)10   .
# factor(occ2)8:factor(ind2)10   .
# factor(occ2)9:factor(ind2)10   .
# factor(occ2)10:factor(ind2)10  .
# factor(occ2)11:factor(ind2)10  .
# factor(occ2)12:factor(ind2)10  .
# factor(occ2)13:factor(ind2)10  .
# factor(occ2)14:factor(ind2)10  2.421118e-01
# factor(occ2)15:factor(ind2)10 -4.843468e-01
# factor(occ2)16:factor(ind2)10 -6.894235e-04
# factor(occ2)17:factor(ind2)10 -3.846910e-03
# factor(occ2)18:factor(ind2)10  .
# factor(occ2)19:factor(ind2)10  .
# factor(occ2)20:factor(ind2)10 -6.328081e-02
# factor(occ2)21:factor(ind2)10  6.806053e-01
# factor(occ2)22:factor(ind2)10  8.068485e-02
# factor(occ2)2:factor(ind2)11   4.090104e-01
# factor(occ2)3:factor(ind2)11  -3.354301e-01
# factor(occ2)4:factor(ind2)11  -1.551409e-02
# factor(occ2)5:factor(ind2)11   .
# factor(occ2)6:factor(ind2)11   .
# factor(occ2)7:factor(ind2)11   6.240200e-01
# factor(occ2)8:factor(ind2)11  -2.095092e-01
# factor(occ2)9:factor(ind2)11  -1.336953e-01
# factor(occ2)10:factor(ind2)11  .
# factor(occ2)11:factor(ind2)11  .
# factor(occ2)12:factor(ind2)11  .
# factor(occ2)13:factor(ind2)11  .
# factor(occ2)14:factor(ind2)11 -5.911932e-01
# factor(occ2)15:factor(ind2)11  .
# factor(occ2)16:factor(ind2)11  1.880119e-01
# factor(occ2)17:factor(ind2)11 -3.080014e-02
# factor(occ2)18:factor(ind2)11  .
# factor(occ2)19:factor(ind2)11 -4.058683e-01
# factor(occ2)20:factor(ind2)11 -1.673671e-02
# factor(occ2)21:factor(ind2)11  .
# factor(occ2)22:factor(ind2)11  1.074649e-01
# factor(occ2)2:factor(ind2)12   .
# factor(occ2)3:factor(ind2)12   9.495180e-02
# factor(occ2)4:factor(ind2)12   .
# factor(occ2)5:factor(ind2)12   .
# factor(occ2)6:factor(ind2)12   .
# factor(occ2)7:factor(ind2)12   6.876633e-01
# factor(occ2)8:factor(ind2)12  -6.563352e-01
# factor(occ2)9:factor(ind2)12   .
# factor(occ2)10:factor(ind2)12  8.783278e-02
# factor(occ2)11:factor(ind2)12  .
# factor(occ2)12:factor(ind2)12  2.866169e-01
# factor(occ2)13:factor(ind2)12  .
# factor(occ2)14:factor(ind2)12 -2.306698e-01
# factor(occ2)15:factor(ind2)12  .
# factor(occ2)16:factor(ind2)12  6.030668e-03
# factor(occ2)17:factor(ind2)12 -1.969156e-01
# factor(occ2)18:factor(ind2)12  .
# factor(occ2)19:factor(ind2)12  4.589284e-01
# factor(occ2)20:factor(ind2)12 -8.949250e-02
# factor(occ2)21:factor(ind2)12  .
# factor(occ2)22:factor(ind2)12  .
# factor(occ2)2:factor(ind2)13   .
# factor(occ2)3:factor(ind2)13   .
# factor(occ2)4:factor(ind2)13   .
# factor(occ2)5:factor(ind2)13   .
# factor(occ2)6:factor(ind2)13   .
# factor(occ2)7:factor(ind2)13   .
# factor(occ2)8:factor(ind2)13   .
# factor(occ2)9:factor(ind2)13   .
# factor(occ2)10:factor(ind2)13  .
# factor(occ2)11:factor(ind2)13  .
# factor(occ2)12:factor(ind2)13  .
# factor(occ2)13:factor(ind2)13  .
# factor(occ2)14:factor(ind2)13  .
# factor(occ2)15:factor(ind2)13  7.535554e-03
# factor(occ2)16:factor(ind2)13  5.232317e-02
# factor(occ2)17:factor(ind2)13  1.101799e-01
# factor(occ2)18:factor(ind2)13  .
# factor(occ2)19:factor(ind2)13  .
# factor(occ2)20:factor(ind2)13  2.071123e-01
# factor(occ2)21:factor(ind2)13  .
# factor(occ2)22:factor(ind2)13 -4.694995e-02
# factor(occ2)2:factor(ind2)14   5.199067e-02
# factor(occ2)3:factor(ind2)14   1.196437e-01
# factor(occ2)4:factor(ind2)14   7.825532e-02
# factor(occ2)5:factor(ind2)14  -1.834155e-01
# factor(occ2)6:factor(ind2)14   .
# factor(occ2)7:factor(ind2)14   .
# factor(occ2)8:factor(ind2)14   7.074817e-02
# factor(occ2)9:factor(ind2)14   8.245695e-02
# factor(occ2)10:factor(ind2)14  3.833504e-01
# factor(occ2)11:factor(ind2)14 -2.778136e-01
# factor(occ2)12:factor(ind2)14  .
# factor(occ2)13:factor(ind2)14  .
# factor(occ2)14:factor(ind2)14 -7.950939e-01
# factor(occ2)15:factor(ind2)14  .
# factor(occ2)16:factor(ind2)14  2.054253e-01
# factor(occ2)17:factor(ind2)14  .
# factor(occ2)18:factor(ind2)14  .
# factor(occ2)19:factor(ind2)14 -2.207288e-01
# factor(occ2)20:factor(ind2)14 -7.221427e-01
# factor(occ2)21:factor(ind2)14  2.204152e-01
# factor(occ2)22:factor(ind2)14  5.716092e-02
# factor(occ2)2:factor(ind2)15  -2.409142e-02
# factor(occ2)3:factor(ind2)15   .
# factor(occ2)4:factor(ind2)15   .
# factor(occ2)5:factor(ind2)15   .
# factor(occ2)6:factor(ind2)15   .
# factor(occ2)7:factor(ind2)15   .
# factor(occ2)8:factor(ind2)15   .
# factor(occ2)9:factor(ind2)15   .
# factor(occ2)10:factor(ind2)15  .
# factor(occ2)11:factor(ind2)15  .
# factor(occ2)12:factor(ind2)15  .
# factor(occ2)13:factor(ind2)15  .
# factor(occ2)14:factor(ind2)15  .
# factor(occ2)15:factor(ind2)15  .
# factor(occ2)16:factor(ind2)15  .
# factor(occ2)17:factor(ind2)15  .
# factor(occ2)18:factor(ind2)15  .
# factor(occ2)19:factor(ind2)15  .
# factor(occ2)20:factor(ind2)15  .
# factor(occ2)21:factor(ind2)15  .
# factor(occ2)22:factor(ind2)15  .
# factor(occ2)2:factor(ind2)16   1.179647e-01
# factor(occ2)3:factor(ind2)16   7.891227e-02
# factor(occ2)4:factor(ind2)16   .
# factor(occ2)5:factor(ind2)16   2.983981e-01
# factor(occ2)6:factor(ind2)16   .
# factor(occ2)7:factor(ind2)16   8.319944e-02
# factor(occ2)8:factor(ind2)16   .
# factor(occ2)9:factor(ind2)16   3.042643e-02
# factor(occ2)10:factor(ind2)16  .
# factor(occ2)11:factor(ind2)16  .
# factor(occ2)12:factor(ind2)16 -8.621526e-02
# factor(occ2)13:factor(ind2)16  .
# factor(occ2)14:factor(ind2)16 -2.307623e-01
# factor(occ2)15:factor(ind2)16  .
# factor(occ2)16:factor(ind2)16  8.842230e-02
# factor(occ2)17:factor(ind2)16  6.928414e-03
# factor(occ2)18:factor(ind2)16  .
# factor(occ2)19:factor(ind2)16  .
# factor(occ2)20:factor(ind2)16 -1.094773e-01
# factor(occ2)21:factor(ind2)16  .
# factor(occ2)22:factor(ind2)16 -2.271786e-01
# factor(occ2)2:factor(ind2)17   .
# factor(occ2)3:factor(ind2)17  -3.541580e-02
# factor(occ2)4:factor(ind2)17  -1.942392e-01
# factor(occ2)5:factor(ind2)17  -5.795980e-02
# factor(occ2)6:factor(ind2)17   3.555611e-01
# factor(occ2)7:factor(ind2)17   2.057471e-01
# factor(occ2)8:factor(ind2)17   .
# factor(occ2)9:factor(ind2)17   .
# factor(occ2)10:factor(ind2)17 -2.072596e-01
# factor(occ2)11:factor(ind2)17  .
# factor(occ2)12:factor(ind2)17  .
# factor(occ2)13:factor(ind2)17 -5.133090e-01
# factor(occ2)14:factor(ind2)17  .
# factor(occ2)15:factor(ind2)17  1.883666e-01
# factor(occ2)16:factor(ind2)17  4.020604e-01
# factor(occ2)17:factor(ind2)17  1.934250e-02
# factor(occ2)18:factor(ind2)17  .
# factor(occ2)19:factor(ind2)17  .
# factor(occ2)20:factor(ind2)17  3.234891e-01
# factor(occ2)21:factor(ind2)17  .
# factor(occ2)22:factor(ind2)17 -6.685849e-02
# factor(occ2)2:factor(ind2)18   9.710611e-03
# factor(occ2)3:factor(ind2)18   2.420666e-01
# factor(occ2)4:factor(ind2)18   .
# factor(occ2)5:factor(ind2)18  -1.535368e-01
# factor(occ2)6:factor(ind2)18   .
# factor(occ2)7:factor(ind2)18   .
# factor(occ2)8:factor(ind2)18  -9.618508e-02
# factor(occ2)9:factor(ind2)18   .
# factor(occ2)10:factor(ind2)18  1.061576e-02
# factor(occ2)11:factor(ind2)18  .
# factor(occ2)12:factor(ind2)18  5.668748e-02
# factor(occ2)13:factor(ind2)18  .
# factor(occ2)14:factor(ind2)18  5.366526e-02
# factor(occ2)15:factor(ind2)18 -1.321996e-01
# factor(occ2)16:factor(ind2)18  .
# factor(occ2)17:factor(ind2)18  1.129178e-02
# factor(occ2)18:factor(ind2)18  .
# factor(occ2)19:factor(ind2)18  9.533178e-02
# factor(occ2)20:factor(ind2)18  .
# factor(occ2)21:factor(ind2)18 -2.995623e-01
# factor(occ2)22:factor(ind2)18 -1.077559e-01
# factor(occ2)2:factor(ind2)19  -2.542703e-01
# factor(occ2)3:factor(ind2)19  -9.409694e-02
# factor(occ2)4:factor(ind2)19   .
# factor(occ2)5:factor(ind2)19  -9.371964e-03
# factor(occ2)6:factor(ind2)19   .
# factor(occ2)7:factor(ind2)19  -3.303469e-01
# factor(occ2)8:factor(ind2)19  -8.535830e-02
# factor(occ2)9:factor(ind2)19  -2.211354e-02
# factor(occ2)10:factor(ind2)19  .
# factor(occ2)11:factor(ind2)19  .
# factor(occ2)12:factor(ind2)19 -8.298240e-01
# factor(occ2)13:factor(ind2)19  .
# factor(occ2)14:factor(ind2)19  9.085027e-03
# factor(occ2)15:factor(ind2)19 -2.144478e-01
# factor(occ2)16:factor(ind2)19 -3.763447e-01
# factor(occ2)17:factor(ind2)19 -7.233819e-02
# factor(occ2)18:factor(ind2)19  .
# factor(occ2)19:factor(ind2)19  .
# factor(occ2)20:factor(ind2)19 -4.721377e-01
# factor(occ2)21:factor(ind2)19  .
# factor(occ2)22:factor(ind2)19 -7.960184e-01
# factor(occ2)2:factor(ind2)20  -2.032736e-01
# factor(occ2)3:factor(ind2)20  -4.910626e-01
# factor(occ2)4:factor(ind2)20   .
# factor(occ2)5:factor(ind2)20   .
# factor(occ2)6:factor(ind2)20   .
# factor(occ2)7:factor(ind2)20   .
# factor(occ2)8:factor(ind2)20  -1.270251e-02
# factor(occ2)9:factor(ind2)20   .
# factor(occ2)10:factor(ind2)20  .
# factor(occ2)11:factor(ind2)20  .
# factor(occ2)12:factor(ind2)20  1.908939e-02
# factor(occ2)13:factor(ind2)20  .
# factor(occ2)14:factor(ind2)20 -6.930123e-02
# factor(occ2)15:factor(ind2)20  .
# factor(occ2)16:factor(ind2)20 -3.250273e-01
# factor(occ2)17:factor(ind2)20  7.617831e-02
# factor(occ2)18:factor(ind2)20  .
# factor(occ2)19:factor(ind2)20 -1.163546e-01
# factor(occ2)20:factor(ind2)20 -3.436946e-01
# factor(occ2)21:factor(ind2)20  2.230842e-01
# factor(occ2)22:factor(ind2)20  4.745185e-02
# factor(occ2)2:factor(ind2)21   .
# factor(occ2)3:factor(ind2)21  -3.175396e-01
# factor(occ2)4:factor(ind2)21   6.385484e-01
# factor(occ2)5:factor(ind2)21   .
# factor(occ2)6:factor(ind2)21  -1.184868e-01
# factor(occ2)7:factor(ind2)21   .
# factor(occ2)8:factor(ind2)21   .
# factor(occ2)9:factor(ind2)21   2.526973e-02
# factor(occ2)10:factor(ind2)21 -1.727032e-01
# factor(occ2)11:factor(ind2)21  .
# factor(occ2)12:factor(ind2)21  .
# factor(occ2)13:factor(ind2)21 -2.920827e-01
# factor(occ2)14:factor(ind2)21  .
# factor(occ2)15:factor(ind2)21  .
# factor(occ2)16:factor(ind2)21  3.203942e-03
# factor(occ2)17:factor(ind2)21 -6.260812e-02
# factor(occ2)18:factor(ind2)21 -3.775294e-02
# factor(occ2)19:factor(ind2)21  .
# factor(occ2)20:factor(ind2)21  1.197012e-01
# factor(occ2)21:factor(ind2)21  4.856882e-02
# factor(occ2)22:factor(ind2)21  .
# factor(occ2)2:factor(ind2)22   .
# factor(occ2)3:factor(ind2)22   7.542825e-02
# factor(occ2)4:factor(ind2)22  -3.214453e-01
# factor(occ2)5:factor(ind2)22   7.801139e-02
# factor(occ2)6:factor(ind2)22   .
# factor(occ2)7:factor(ind2)22   .
# factor(occ2)8:factor(ind2)22   .
# factor(occ2)9:factor(ind2)22  -2.478644e-01
# factor(occ2)10:factor(ind2)22 -5.560411e-01
# factor(occ2)11:factor(ind2)22 -5.383719e-03
# factor(occ2)12:factor(ind2)22  .
# factor(occ2)13:factor(ind2)22  .
# factor(occ2)14:factor(ind2)22  .
# factor(occ2)15:factor(ind2)22 -1.372121e+00
# factor(occ2)16:factor(ind2)22 -2.985413e-01
# factor(occ2)17:factor(ind2)22 -9.817704e-02
# factor(occ2)18:factor(ind2)22  6.016473e-02
# factor(occ2)19:factor(ind2)22 -1.007893e-01
# factor(occ2)20:factor(ind2)22  6.813457e-02
# factor(occ2)21:factor(ind2)22  9.440473e-02
# factor(occ2)22:factor(ind2)22  2.519165e-02
